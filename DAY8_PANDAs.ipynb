# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu-Meshram/UM-Python/blob/main/DAY8_PANDAs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas Series**
#
#
# *   A Pandas Series is like a column in a table.
# *   It is a one-dimensional array holding data of any type.

# %%
import pandas as pd                                                             # IMPORTING PANDAS

# series = pd.Series([1,88,33,55,44])                                                                           # Accessing Pandas series
# print(series)                                                                                                 # output is in column and with indexing



                                                                                # Series Method with Index

SI = pd.Series([1,88,33,55,44],index = ['a','b','c','d','e'])                                                 # index numbers = length of elements
# print(SI)                                                                                                     # syntax {([elements],index=[elements'',""])}



                                                                                # Accessing Series elements

# print(SI['a'])                                                                                                # syntax {print(variable[index-value])}
# print(SI['d'])

# %% [markdown]
# # **Data Frame**
#
#
# *   A Data frame is a two-Dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.

# %%
# data = pd.DataFrame([1,2,3,4,5])                                               # DataFrame
# print(data)                                                                                                                # Accessing DataFrame



#                                                                                # DataFrame using Dictionary

# data = pd.DataFrame({'Name' : ['Rat','Bat','Cat','Mice','Dog','Yoo','Yup'],                                                #syntax DataFrame({'variable':['values'],
#                      'Age':[8,5,10,12,16,18,22]})                              #                                                              'variable':['values]})

# data.head()                                                                                                                # Similar to print but good visuals
#                                                                                                                            # Default = top 5 values
# data.head(10)                                                                                                              # (10) denotes number of values to be display

# print(data)



###-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------


#                                                                                # DataFrame with indexing using dictionary

# data = pd.DataFrame({'Name':['Rahul','Palak','Sam','Guy','Dude','Boii'],                                                      # syntax ({Name : [],Age : []},index = [])
#                      'Age': [21,33,42,19,22,23]},
#                      index=['a','b','c','d','e','f'])

# data.head(10)





###-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------


#                                                                                # Column Selection

# data['Name']                                                                                                                    # Syntax   data['column-name']
# data['Age']
# data[['Name','Age']]                                                                                                            # for more columns   data[['column1','column2']]



###-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------


#                                                                                # Row Selection


# data.loc['b','Name']                                                                                                              # loc > location                 "Lables"
# data.loc['b','Age']                                                                                                               # syntax {data.loc['row','column']}

# data.iloc[1,0]                                                                                                                    # iloc > "integer" location
# data.iloc[1,1]                                                                                                                    # syntax {data.iloc['row','column']}
# Out:
#     Name  Age
# a  Rahul   21
# b  Palak   33
# c    Sam   42
# d    Guy   19
# e   Dude   22
# f   Boii   23

# %% [markdown]
# # **Pandas Concatenation**
#
#
# *   It is used to concatenate pandas objects along a particular axis with optional set logic along the other axis.

# %%
import pandas as pd
                                                                                # Creating data frames


names = pd.DataFrame({'Name':['Rahul','Roshan','Jetha','Popat','Haathi','Mehta','Bhide']})
age = pd.DataFrame({'Age':[22,55,33,66,44,22,25]})

name1 = pd.DataFrame({'Name': ['Tom','Jerry','Jack','Little','Josh','Benz','Vik']})


# names.head(10)
# age.head(10)
# name1.head(10)


#                                                                               # Before concatenate both dataframes should have equal no. of values/data.

                                                                                # Concatenate

# pd.concat([names,age],axis=1)                                                                             # syntax    pd.concat([column1,column2],axis=1)
# data = pd.concat([name1,age],axis=1)                                                                             #                         axis = 1 > column   :: 0 > row
# data.head(10)


# pd.concat([names,name1])                                                                                  # to continue same set of values
# pd.concat([names,name1],axis=0).reset_index()                                                             # " .reset_index() "     >   for  reset the index
# Out:
#      Name  Age
# 0     Tom   22
# 1   Jerry   55
# 2    Jack   33
# 3  Little   66
# 4    Josh   44
# 5    Benz   22
# 6     Vik   25

# %% [markdown]
# # **Pandas Indexing**
#
#
# * loc()
# * iloc()
# * Filtering

# %%
data.head(10)                                                                                       # Accessing data

# data['Name']                                                                                      # Accessing only one column

# data[['Name','Age']]                                                                              # Accessing more columns


###-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------


                                                                                # Filtering Method
# data[data['Age']>=25]
# data[data['Age']<=35]
# data[data['Age']<=25][['Name']]
# data[data['Age']<=25][['Name','Age']]                                                               # syntax   data[data['column-name']--condition--][['output-columns']]




# data.loc[2,'Name']                                                                                  # loc > location                 "Lables"
# data.loc[3,'Name']                                                                                  # syntax {data.loc['row','column']}


# data.iloc[2,1]                                                                                      # iloc > "integer" location
# data.iloc[2,0]                                                                                      # syntax {data.iloc['row','column']}
# Out:
# 'Little'

# %%
#
