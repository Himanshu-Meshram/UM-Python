# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu-Meshram/UM-Python/blob/main/Day12_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EDA- Exploratory Data Analysis**
# **HANDLING OUTLIERS USING IQR - inter-quadral-range**
#
# * np.percentile()
# * upp = Q1 - 1.5*IQR
# * low = Q2 + 1.5*IQR
# * Outliners
#
#
# ![12EDA.png](data:image/png;base64,...)

# %%
import numpy as np

List = [1,2,3,4,5,6,9,10,12,55,60]
## List = [23,1,2,65,11,4,3,5,9,8,75,]                                            ### 1st arrange the Data in Ascending Order.


                                                                                  ## FINDING 25% of my Data.
                                                                                  ## we'll store  "25%" of the data in Q1.

# Q1 = np.percentile(List,25)                                                     ## shows 1st 25% percentile..*

# print(Q1)



# Q2 = np.percentile(List,75)
# Q2



# IQR = Q2 - Q1
# IQR                                                                               ## Median of IQR



                                                                          ##------ Find Lower Quartile value

# low = Q1 - 1.5*IQR                                                                      ## 1.5 is the constant value.
# low


                                                                          ##------ Find Upper Quartile value

# Upp = Q2 + 1.5*IQR                                                                      ## 1.5 is the constant value.
# Upp



Outliners = []                                                          ##-------- Creating an Empty List for Outliners to store futher conditions.


# for i in List:                                                                  ## if-else statement to enter the values.
#   if ((i>Upp) or (i<low)):
#     Outliners.append(i)

# print(Outliners)





# for i in List:                                                                    ## Values not present in Outliners.
#   if i not in Outliners:
#     print(i)


# List = [i for i in List if i not in Outliners]                                   ## saving them in the orignal outliner.
# List
# Out:
# [55, 60]
# 1
# 2
# 3
# 4
# 5
# 6
# 9
# 10
# 12
# [1, 2, 3, 4, 5, 6, 9, 10, 12]

# %% [markdown]
# # **Duplicates**
#
#
# *   data.duplicated()
# *   data.drop_duplicates()

# %%
import numpy as np
import pandas as pd


data = pd.DataFrame({'Team' : ['MI','MI','RCB','KKR','DC','RR','SRH','SRH'],
                              'Points' : [10,10,12,12,15,15,20,20],
                              'Assists' : [5,5,7,12,12,9,6,6]})

## data1 = pd.DataFrame({'Team' : ['MI','MI','RCB','KKR','DC','RR','SRH','SRH'],
##                                'Points' : [10,10,12,12,12,15,20,20],
##                                'Assists' : [5,5,7,12,12,9,6,6]})


# data
## data1


# data.duplicated()                                                             ## Looking for Duplicates in all columns
                                                                                              ## columns should be different

# data[data.duplicated()]                                                                   ## storing duplicates in data...
                                                                                            ## Displays more clearly



# data.duplicated(['Team'])                                                     ## Looking for Duplicates in one column
# data[data.duplicated(['Team'])]                                                             ## Displays more clearly

##data1[data.duplicated(['Team'])]




# data.duplicated(['Points','Assists'])                                         ## Looking for Duplicates in multiple columns
# data[data.duplicated(['Points','Assists'])]

## data[data.duplicated(['Points','Assists'])]


                                                                                ## Droping Duplicatess
# data.drop_duplicates()

# data.drop_duplicates(['Team'])                                                     ## Droping for Duplicates in one column
# data_new = data.drop_duplicates(['Team'])
# data,data_new


# data.drop_duplicates(['Points','Assists'])                                                     ## Droping for Duplicates in multiple columns
# Out:
#   Team  Points  Assists
# 0   MI      10        5
# 2  RCB      12        7
# 3  KKR      12       12
# 4   DC      15       12
# 5   RR      15        9
# 6  SRH      20        6
