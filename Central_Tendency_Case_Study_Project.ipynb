# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu-Meshram/UM-Python/blob/main/Central_Tendency_Case_Study_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Central Tendency Case Study Project**

# %% [markdown]
# # **INTRODUCTION**
#
# This Jupiter notebook is part of your learning experience in the study of central tendency
# We will work with a simple data set that contains details of wine quality
# In this exercise, we will perform the following tasks:
# 1. Load and Study the data.
# 2. View the distribution of the various features in the data set and calculate their tendencies
# 3. Create a new Pandas Series that contains the details of the representative factor for quality
#
# # **TASK 1 - Load and Study the Data**
#
# Load the data and study its features such as:
#
# * Fixed Acidity
# * Volatile Acidity
# * Citric Acid etc.

# %%
## importing NUMPY AND PANDAS LIBRARY for manipulating numbers and dat frames
## import MATPLOTLIB and SEABORN for data visualization

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Read in the "winequality-white.csv" file as a pandas DataFrame
data = pd.read_csv('/content/Day19 Wine Quality Dataset.csv')

# %%
## Take a Breif look at my dataset
# data.head()

# %%
## Dimensions of the dataset
# data.shape

# %%
## Rows names and Number of the DataFrame
# data.index

# %%
## Columns Names of the DataFrame
# data.columns

# %%
## Look at the basic information of the DataFrame
# data.info()

# %% [markdown]
# >   **Obseravtion from TASK 1**
#
# There are 4898 rows and 12 columns in the data.
# Each row contains the details of the types of acids present in white-wine and the quality.
# The features in the data set are:
# * Different acids and their Quality

# %% [markdown]
# # **TASK 2 -** View the distribution of the various features in the data set and calculate their central tendencies.
#
# we will look at their distributions of the various features in the data set.
#
# we will also calculate appropriate measures of central tendencies for these features.

# %%
## Creating a Histogram of the "Fixed acidity" column

# plt.figure(figsize=(5,4))                                                        ## used matplotlib lib.

# plt.hist(data = data, x='fixed acidity', color = 'orange',                        ## data >> access the data from their
#         edgecolor = 'b',alpha = 0.5, bins =5)                                     ## alpha >> adjust the contrast of the color
# plt.title('Histogram of Fixed Acidity')                                           ## bins >> x-axis values
# plt.xlabel('Fixed Acidity')
# plt.ylabel('Count')
# plt.show()

# %% [markdown]
# **Observations**
# We Observe that the histogramis normally distributed.
#
# The maximum count of values for fixed acidity lies in between 6 to 8.
#
# Lets see the measure of central tendency in working!
# 1. Mean
# 2. Median
# 3. Mode
#
# ![image.png](data:image/png;base64,...)

# %%
## Calculate the mean of "Fixed Acidity"

# data['fixed acidity'].mean()
round(data['fixed acidity'].mean(),2)
# Out:
# 6.85

# %%
## Calculating the median of "Fixed Acidity"

data['fixed acidity'].median()
# Out:
# 6.8

# %%
## Create a histogram of the "Fixed Acidity" and show the mean and the median

plt.figure(figsize=(10,5))

sns.histplot(data=data, x='fixed acidity', color='orange',                        ## here we have used seaborn lib.
            edgecolor = 'w', alpha=0.5, bins=5)
plt.title('Histogram of Fixed Acidity')
plt.xlabel('fixed acidity')
plt.ylabel('Count')

plt.vlines(data['fixed acidity'].mean(),ymin = 0, ymax = 4000, color = 'blue', label = 'Mean')          ## syntax >> plt.vlines(-data_variable-['column'].mean/mode/median, ymin=,ymax=,............)
plt.vlines(data['fixed acidity'].median(), ymin = 0, ymax = 4000, color = 'red', label = 'Median')      ## plt.vlines == vertical lines, ymin == yminimum, ymax == ymaximum
plt.legend()                                                                                            ## used to make scale / legend
plt.show()

# %% [markdown]
# **Observations**
#
# We can see that the mean and median are clear representative of the data.
# Mean and Median are very close to each other.
#
# We can choose either of the parameters say mean as the measure of central tendency.

# %%
## Create a Histgram of "Volatie Acidity"

plt.figure(figsize=(10,5))

sns.histplot(data=data, x='volatile acidity', color = 'green',
             edgecolor = 'w', alpha = 0.5, bins = 5)
plt.title('Histogram of Volatile Acidity')
plt.xlabel('Volatile Acidity')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Observations**
#
# We Observe that the histogram is not well distributed, it is skewed a little towards the right.
#
# As we have seen skewness, therefore we can check the distribution using displot function.
#
#
#
# *Do you know skewness?*
#
# *  eg. of skewness
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Skewness : Some distribution of data, such as the bell curve or normal distribution, are symmetric.This means that the right and the left of the distribution are prefect mirror of one another. Not every distribution of data is symmetric. Sets of data that are not symmetric are said to be asymmetric.The measure of how asymmetric a distribution can be is called skewness.
#
# The mean,median and mode are all measures of the center of a set of data.The skewness of the data can be determined by how these quantities are related to one another.
# * If Skewness (S) = 0, then the distribution is normally distributed.
# * If Skewness (S) > 0, then the distribution is positively skewed.
# * If skewness (S) < 0, then the distribution is negativily skewed.

# %%
## Plot distplot using "volatile Acidity" column

plt.figure(figsize=(10,5))

sns.distplot(data ['volatile acidity'], color = 'red')
plt.title('Distribution plot of Volatile Acidity')
plt.xlabel('Volatile Acidity')
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-26-0d98f8bc98ff>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data ['volatile acidity'], color = 'red')

# %% [markdown]
# **Observation**
#
# The above plot shows the normal distribution.
#
# The normal distribution is discribed by the mean and the standard deviation.
#
# The normal distribution is often reffered to as a 'bell curve' because of its shape:
# * The median and mean are equal.
# * It has only one mode.
# * It is symmetric, meaning it decreases the same amount on the left and the right of the center.
#
#
# We can calculate skewness too using skew() function in python.

# %%
  ## To Calculate Skewness of "Volatile Acidity"
  # data['volatile acidity'].skew()

  round(data['volatile acidity'].skew(),3)
# Out:
# 1.577

# %% [markdown]
# **Observation**
#  We can clearly see that the skewness value is greater than 1, hence it is positively skewed.

# %%
## calculate the mean of "Volatile Acidity"
round(data['volatile acidity'].mean(),3)
# Out:
# 0.278

# %%
## calculate the median of "Volatile Acidity"
data['volatile acidity'].median()
# Out:
# 0.26

# %%
##  Create Histgram of "Volatile Acidity" and also show the mean and median

plt.figure(figsize=(10,5))

sns.histplot(data=data, x = 'volatile acidity', color = 'purple',
             edgecolor = 'blue', alpha = 0.5, bins = 5)
plt.title('Histogram of Volatile Acidity')
plt.xlabel('Volatile Acidity')
plt.ylabel('Count')

plt.vlines(data['volatile acidity'].mean(),ymin = 0, ymax=4000, color = 'red',label = 'mean')
plt.vlines(data['volatile acidity'].median(),ymin=0,ymax=4000,color = 'green',label='median')
plt.legend()
plt.show()

# %% [markdown]
# **Observations**
#
# The mean and the median are close to each other and the difference between them is very small.
#
# We can safely choose the mean as the measure of the central tendency here.

# %%
## Create a histogram of the "citric acid " column

plt.figure(figsize=(10,5))

sns.histplot(data=data, x='citric acid', color = "cyan",
             edgecolor = 'w', alpha = 0.6, bins = 5)
plt.title('Histogram of Citric Acid')
plt.xlabel('Citric Acid')
plt.ylabel('Count')
plt.show()


data['citric acid'].skew()
# Out:
# 1.2819203981671066

# %% [markdown]
# **Observations**
#
# We observe that this histogram is not well distributed, it is skewed a little towards the right.

# %%
## Calculate the "Citric acid" mean
# data['citric acid'].mean()
round(data['citric acid'].mean(),2)
# Out:
# 0.33

# %%
## Calculate the "Citric Acid" median
data['citric acid'].median()
# Out:
# 0.32

# %%
## Create a histogram of the "Citric Acid" column and also show mean and the median

plt.figure(figsize=(10,5))

sns.histplot(data=data, x="citric acid", color = 'red',
             edgecolor = 'pink', alpha = 0.5, bins = 5)
plt.title('Histogram of Citric Acid')
plt.xlabel('Citric Acid')
plt.ylabel('Count')
plt.vlines(data['citric acid'].mean(),ymin=0,ymax=4000,color='cyan',label='Mean')
plt.vlines(data['citric acid'].median(),ymin=0,ymax=4000,color='yellow',label='Median')
plt.legend()
plt.show()

# %% [markdown]
# **Observations**
#
# The mean and the median are close to each other and the difference between them is very small.
#
# We can safely choose the mean as the measure of the central tendency here.

# %%
## Calculate the displot using "citric acidity" column

plt.figure(figsize=(10,5))

sns.distplot(data['citric acid'], color='blue')
plt.title('Distribution plot of Citric Acid')
plt.xlabel('Citric Acid')
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-35-696722e0abc8>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['citric acid'], color='blue')

# %% [markdown]
# Same Procedure we can follow for other numerical columns to get the mean, median(parameters of central tendency)

# %%
## Create a count plot of the "Quality" feature
plt.figure(figsize=(10,5))

sns.countplot(data=data,x='quality')
plt.title('Count Plot of Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Observations**
#
# It is quite clear from the count plot that the 6 is the highest count of quality, whereas 9 is negligible.

# %%
## Count the number of occurances of different categories of the "Quality" column

data['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
### data.head()

# %%
## Calculate the mode of the "Quality" Column

# data['quality'].mode()
# data['quality'].value_counts().index[0]
# Out:
# 6

# %% [markdown]
# >  **Observations from Task 2**
#
# We saw the distribution of the various features in the data set using appropriate plots.
#
# We calculated central tendency measures like mean, median and mode for the various features.
#
# The mean and the median for all the above features were similar, so we choose the mean in these cases.
#
# The mode of the "Quality" feature can be chosen as a representative value.

# %% [markdown]
# # **TASK 3 -** Create a new Pandas Series that contains the details of the acid types for a quality
#
# We will now create a Pandas Series that contains the representative values for each of the features.

# %%
## Create a new Pandas Series called "rep_acid" that contians the details of the representative quality for the different types of acids

rep_acid = pd.DataFrame(index=['fixed acidity','volatile acidity','citric acid','qualtiy'],
                        data=[data['fixed acidity'].mean(),data['volatile acidity'].mean(),
                              data['citric acid'].mean(),data['quality'].value_counts().index[0]])
rep_acid
# Out:
#                          0
# fixed acidity     6.854788
# volatile acidity  0.278241
# citric acid       0.334192
# qualtiy           6.000000

# %% [markdown]
# > **Observations from Task 3**
#
#  The representative acid for the quality is as follows:
# 1. The mean value of the fixed acidity would be 6.854
# 2. The mean value of the volatile acidity would be 0.2752
# 3. The mean value of the citric acid would be 0.3341
# 4. The quality would be 6.

# %% [markdown]
# ***FINAL CONCLUSIONS***
# * From the given data, we can use simple visualisations to get a sense of how data are distributed.
# * We can use various measures of tendency such as mean, median, mode to represent a group of observations.
# * The type of central tendency measures to use depends on the type and the distribution of the data.
